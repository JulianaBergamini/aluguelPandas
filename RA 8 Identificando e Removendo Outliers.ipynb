# %% [markdown]
# # Relatório de Análise VIII
# ## Identificando e Removendo Outliers

# %%
# outliers: divergências nos dados
# utilizaremos o box-plot para visualizar isso

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

plt.rc('figure', figsize = (14,6))

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')

# %%
dados.boxplot(['Valor'])
# Out:
# <AxesSubplot:>

# %%
dados[dados['Valor'] >= 500000]
# Out:
#                           Tipo                    Bairro  Quartos  Vagas  \
# 731    Conjunto Comercial/Sala           Barra da Tijuca        0      0
# 774    Conjunto Comercial/Sala                  Botafogo        0     56
# 1022   Conjunto Comercial/Sala               Cidade Nova        0     47
# 2370   Conjunto Comercial/Sala                    Centro        0     15
# 4812   Conjunto Comercial/Sala                    Centro        0     30
# 7254   Conjunto Comercial/Sala                    Centro        0      1
# 9246   Conjunto Comercial/Sala               Cidade Nova        0     80
# 10150              Apartamento           Barra da Tijuca        1      1
# 10629  Conjunto Comercial/Sala                    Centro        0      2
# 13332  Conjunto Comercial/Sala                    Centro        0     27
# 14047       Casa de Condomínio   Freguesia (Jacarepaguá)        4      2
# 14337  Conjunto Comercial/Sala                    Glória        0     40
# 16698              Apartamento   Freguesia (Jacarepaguá)        2      2
# 18238              Apartamento  Recreio dos Bandeirantes        3      2
# 19849  Conjunto Comercial/Sala           Barra da Tijuca        0      1
# 20333  Conjunto Comercial/Sala                    Centro        0      0
# 20378              Apartamento                  Botafogo        4      1
# 22823  Conjunto Comercial/Sala                      Caju        0      0
# 26470  Conjunto Comercial/Sala                  Botafogo        0     42
# 26645  Conjunto Comercial/Sala                   Ipanema        0      1
#
#        Suites   Area      Valor  Condominio     IPTU  Valor m2 Tipo Agregado
# 731         0   5124   614000.0         0.0      0.0    119.83   Apartamento
# 774         0   4235   529375.0    114599.0  34345.0    125.00   Apartamento
# 1022        0   7357   514990.0    166709.0  14787.0     70.00   Apartamento
# 2370        0   5666   530000.0         1.0      1.0     93.54   Apartamento
# 4812        0   4940   612550.0    128440.0      0.0    124.00   Apartamento
# 7254        0     40   900700.0      1050.0    120.0  22517.50   Apartamento
# 9246        0   9600   576000.0    130020.0      0.0     60.00   Apartamento
# 10150       0     65   600000.0       980.0    120.0   9230.77   Apartamento
# 10629       0    545   627394.0     13093.0   3818.0   1151.18   Apartamento
# 13332       0   4442   546840.0    115492.0      0.0    123.11   Apartamento
# 14047       3    163   800000.0       900.0      0.0   4907.98          Casa
# 14337       0   4659   605670.0    152256.0      0.0    130.00   Apartamento
# 16698       1    150   550000.0       850.0    150.0   3666.67   Apartamento
# 18238       1    167  1250000.0      1186.0    320.0   7485.03   Apartamento
# 19849       0     45   550000.0       880.0   1446.0  12222.22   Apartamento
# 20333       0  11216   874895.0    196291.0      0.0     78.00   Apartamento
# 20378       1    300  4500000.0      1100.0      0.0  15000.00   Apartamento
# 22823       0  10660  1279200.0         0.0      0.0    120.00   Apartamento
# 26470       0   4530   679500.0    152706.0  20926.0    150.00   Apartamento
# 26645       0     30   800000.0      1700.0    258.0  26666.67   Apartamento

# %%
valor = dados['Valor']

# %%
Q1 = valor.quantile(.25)
Q3 = valor.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = (valor >=limite_inferior) & (valor <= limite_superior)
dados_new = dados[selecao]

# %%
dados_new.boxplot(['Valor'])
# Out:
# <AxesSubplot:>

# %%
dados.hist(['Valor'])
dados_new.hist(['Valor'])
# Out:
# array([[<AxesSubplot:title={'center':'Valor'}>]], dtype=object)
