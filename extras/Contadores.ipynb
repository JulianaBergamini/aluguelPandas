# %%
import pandas as pd

s = pd.Series(list('asdadeadesdasesda'))
s
# Out:
# 0     a
# 1     s
# 2     d
# 3     a
# 4     d
# 5     e
# 6     a
# 7     d
# 8     e
# 9     s
# 10    d
# 11    a
# 12    s
# 13    e
# 14    s
# 15    d
# 16    a
# dtype: object

# %%
# coletar caracteres disponíveis eliminando repeticoes:

s.unique()
# Out:
# array(['a', 's', 'd', 'e'], dtype=object)

# %%
# saber quantas vezes cada tipo foi utilizado:

s.value_counts()
# Out:
# a    5
# d    5
# s    4
# e    3
# dtype: int64
